# %%
import pandas as pd
attd=pd.read_csv(r"C:\Users\ACER\Desktop\myProj\Facial-Recognition-Based-Student-Attendance-System\pitching-ideas\proposed\attendance1.csv")
attDF=pd.DataFrame(attd)

attDF
# Out:
#        1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021  \
# 0      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 1      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 2      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 3      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 4      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 5      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 6      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 7      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 8      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 9      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 10     1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 11     2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# ...

# %%
# df.to_csv(r"test1.csv", header = ['id', 'Roll', 'Name', 'Dept', 'Time', 'Date', 'Status'], index=False) 
attDF.to_csv(r"attend.csv", header = ['id', 'Roll', 'Name', 'Dept', 'Time', 'Date', 'Status'], index = False)
# Out:
#        1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021  \
# 0      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 1      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 2      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 3      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 4      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 5      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 6      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 7      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 8      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 9      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 10     1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 11     2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# ...

# %%
attDF1 = pd.read_csv(r"C:\Users\ACER\Desktop\myProj\Facial-Recognition-Based-Student-Attendance-System\pitching-ideas\attend.csv")
attDF1=pd.DataFrame(attd)

attDF1
# Out:
#        1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021  \
# 0      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 1      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 2      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 3      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 4      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 5      2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# 6      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 7      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 8      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 9      1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 10     1  171346     Keshav Raj Poudel  Computer  14:06:45   02/10/2021
# 11     2  171347  Khom Raj Thapa Magar  Computer  14:06:46   02/10/2021
# ...

# %%
presentStatus=attDF1["id"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
presentStatus[2]

# %%
recordDF=pd.DataFrame(columns=['ID','Name','Roll Number','Number of Present Days'])
for index, row in attDF.iterrows():
    for id in attDF['ID'].unique():
        if(row["ID"])==id:
            data={'ID':row['ID'], 'Name':row['Name'],'Roll Number':row["Roll_no"], 'Number of Present Days': presentStatus[id]}
            print(data)
            recordDF=recordDF.append(data, ignore_index=True)
# Out:
# {'ID': 1, 'Name': 'Keshav Raj Poudel', 'Roll Number': 171346, 'Number of Present Days': 3}
# {'ID': 1, 'Name': 'Keshav Raj Poudel', 'Roll Number': 171346, 'Number of Present Days': 3}
# {'ID': 1, 'Name': 'Keshav Raj Poudel', 'Roll Number': 171346, 'Number of Present Days': 3}
# {'ID': 2, 'Name': 'Nipesh Shrestha', 'Roll Number': 13422, 'Number of Present Days': 2}
# {'ID': 2, 'Name': 'Nipesh Shrestha', 'Roll Number': 13422, 'Number of Present Days': 2}

# %%
recordDF.drop_duplicates(subset =["ID"], inplace = True)
recordDF

# %%
recordDF.to_csv("MonthlyReport.csv", index=False)

# %%
pd.read_csv("MonthlyReport.csv")
